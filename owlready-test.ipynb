# %%
pip install owlready2

# %%
from owlready2 import *

# %%
onto = get_ontology("file://EDAM_geo_dev.owl").load()

# %%
print(onto.classes)
# Out:
# <bound method _GraphManager.classes of get_ontology("http://edamontology.org/")>

# %%
list(onto.classes())
#THIS IS THE SAME ORDER OF CLASSES AS FROM RDFLIB AllClasses(g)
# Out:
# [EDAM_geo_dev.data_0006,
#  EDAM_geo_dev.format_1915,
#  EDAM_geo_dev.operation_0004,
#  EDAM_geo_dev.data_0842,
#  EDAM_geo_dev.topic_0003,
#  EDAM_geo_dev.data_0005,
#  owl.DeprecatedClass,
#  EDAM_geo_dev.data_2337,
#  EDAM_geo_dev.data_0007,
#  EDAM_geo_dev.data_0958,
#  EDAM_geo_dev.data_0581,
#  EDAM_geo_dev.data_0957,
#  EDAM_geo_dev.data_0582,
#  EDAM_geo_dev.data_2353,
#  EDAM_geo_dev.topic_0089,
#  EDAM_geo_dev.data_0583,
#  EDAM_geo_dev.data_3106,
#  EDAM_geo_dev.data_0831,
#  EDAM_geo_dev.data_0832,
#  EDAM_geo_dev.data_0835,
#  EDAM_geo_dev.data_2048,
#  EDAM_geo_dev.data_0843,
#  EDAM_geo_dev.data_0844,
#  EDAM_geo_dev.data_2050,
#  EDAM_geo_dev.data_0845,
#  EDAM_geo_dev.data_0846,
#  EDAM_geo_dev.data_0847,
#  EDAM_geo_dev.data_0848,
#  EDAM_geo_dev.data_2044,
#  EDAM_geo_dev.data_0849,
#  EDAM_geo_dev.data_0850,
#  EDAM_geo_dev.data_0851,
#  EDAM_geo_dev.data_2534,
#  EDAM_geo_dev.data_0852,
#  EDAM_geo_dev.data_0853,
#  EDAM_geo_dev.data_0854,
# ...

# %%
list(onto.annotation_properties())
# Out:
# [EDAM_geo_dev.next_id,
#  obo.date,
#  obo.idspace,
#  obo.remark,
#  1.1.contributor,
#  1.1.creator,
#  1.1.format,
#  1.1.title,
#  doap.Version,
#  oboInOwl.hasSubset,
#  oboInOwl.savedBy,
#  0.1.page,
#  EDAM_geo_dev.citation,
#  EDAM_geo_dev.created_in,
#  obo.is_metadata_tag,
#  oboInOwl.hasBroadSynonym,
#  oboInOwl.hasDefinition,
#  oboInOwl.hasRelatedSynonym,
#  oboInOwl.inSubset,
#  EDAM_geo_dev.comment_handle,
#  EDAM_geo_dev.deprecation_comment,
#  EDAM_geo_dev.documentation,
#  EDAM_geo_dev.example,
#  EDAM_geo_dev.file_extension,
#  EDAM_geo_dev.hasHumanReadableId,
#  oboInOwl.hasAlternativeId,
#  EDAM_geo_dev.information_standard,
#  oboInOwl.hasNarrowSynonym,
#  EDAM_geo_dev.is_deprecation_candidate,
#  EDAM_geo_dev.is_refactor_candidate,
#  EDAM_geo_dev.isdebtag,
#  EDAM_geo_dev.media_type,
#  EDAM_geo_dev.notRecommendedForAnnotation,
#  EDAM_geo_dev.obsolete_since,
#  EDAM_geo_dev.oldParent,
#  EDAM_geo_dev.oldRelated,
#  EDAM_geo_dev.ontology_used,
# ...

# %%
list(onto.properties())
# Out:
# [EDAM_geo_dev.has_format,
#  EDAM_geo_dev.is_format_of,
#  EDAM_geo_dev.has_function,
#  EDAM_geo_dev.is_function_of,
#  EDAM_geo_dev.has_identifier,
#  EDAM_geo_dev.is_identifier_of,
#  EDAM_geo_dev.has_input,
#  EDAM_geo_dev.is_input_of,
#  EDAM_geo_dev.has_output,
#  EDAM_geo_dev.is_output_of,
#  EDAM_geo_dev.has_topic,
#  EDAM_geo_dev.is_topic_of,
#  EDAM_geo_dev.next_id,
#  obo.date,
#  obo.idspace,
#  obo.remark,
#  1.1.contributor,
#  1.1.creator,
#  1.1.format,
#  1.1.title,
#  doap.Version,
#  oboInOwl.hasSubset,
#  oboInOwl.savedBy,
#  0.1.page,
#  EDAM_geo_dev.citation,
#  EDAM_geo_dev.created_in,
#  obo.is_metadata_tag,
#  oboInOwl.hasBroadSynonym,
#  oboInOwl.hasDefinition,
#  oboInOwl.hasRelatedSynonym,
#  oboInOwl.inSubset,
#  EDAM_geo_dev.comment_handle,
#  EDAM_geo_dev.deprecation_comment,
#  EDAM_geo_dev.documentation,
#  EDAM_geo_dev.example,
#  EDAM_geo_dev.file_extension,
#  EDAM_geo_dev.hasHumanReadableId,
#  oboInOwl.hasAlternativeId,
# ...

# %%
onto.search(iri = "*data_2080")
# Out:
# [EDAM_geo_dev.data_2080]

# %%
onto.save(file = "EDAM_geo_dev.owl", format = "rdfxml")
